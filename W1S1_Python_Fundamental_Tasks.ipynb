# %% [markdown]
# <a href="https://colab.research.google.com/github/mmilannaik/bostonhousepricing/blob/main/W1S1_Python_Fundamental_Tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
# Write your code here
print("Data","Science","Mentorship","Program",sep='-',end='-started-')
print("By","CampusX",sep='-')
# Out:
# Data-Science-Mentorship-Program-started-By-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
# Write your code here
cel_num = input('enter the temp in celsius')
fah_num = float(cel_num) *1.8 +32
print('the temp in fahrenheit is : ',fah_num)
# Out:
# enter the temp in celsius25.4
# the temp in fahrenheit is :  77.72

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
# Write your code here
a=10
b=20
a,b = b,a
print(a)
print(b)
# Out:
# 20
# 10

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
import numpy as np
# Write your code here
x1 = input('Enter x1')

y1 = input('Enter y1')

x2 = input('Enter x2')

y2 = input('Enter y2')

euc_dist = np.sqrt((float(x1)-float(x2))**2 + (float(y1)-float(y2))**2)

print(' euclidean distance is : ',euc_dist)
# Out:
# Enter x15
# Enter y110
# Enter x215
# Enter y210
#  euclidean distance is :  10.0

# %% [markdown]
# 1### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
# Write your code here
p1 = input('enter the principal number')
p2 = input('enter the ROI')
p3 = input('enter the time period in yrs')

print(' the simple_int is :',float(p1)*float(p2)*float(p3)/100)
# Out:
# enter the principal number1000
# enter the ROI5
# enter the time period in yrs2
#  the simple_int is : 100.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
# Write your code here
head = int(input('enter the number of heads '))
legs = int(input('enter the number of legs '))

print(' no of dogs are',head/2,'no of chickens are', head/2)
# Out:
# enter the number of heads 4
# enter the number of legs 12
#  no of dogs are 2.0 no of chickens are 2.0

# %%
# d1 + c1 = 4
# 4d1 + 2c1 = 12

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
# Write your code here
n = int(input('enter the first n natural number for which sum of squares to be calculated '))
sum = 0
for i in range(1,n+1):
  sum = sum + i**2

print(' the sum is ', sum)
# Out:
# enter the first n natural number for which sum of squares to be calculated 5
#  the sum is  55

# %%
n = int(input('enter the first n natural number for which sum of squares to be calculated '))

result = (n*(n+1)*(2*n+1))/6


print(' the sum is ', result)
# Out:
# enter the first n natural number for which sum of squares to be calculated
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-fdde13cb9a80> in <cell line: 1>()
# ----> 1 n = int(input('enter the first n natural number for which sum of squares to be calculated '))
#       2
#       3 result = (n*(n+1)*(2*n+1))/6
#       4
#       5
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
# Write your code here
n1 = int(input('Enter the input no1'))

n2 = int(input('Enter the input no2'))

nterm = int(input('find the nth term for input'))

n3 = n2-n1

print('the nth term is ', n1+(nterm-1)*n3)
# Out:
# Enter the input no13
# Enter the input no26
# find the nth term for input5
# the nth term is  15

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
# Write your code here
n1 = int(input('Enter the numerator for frac1 '))
n2 = int(input('Enter the denominator for frac1 '))
n3 = int(input('Enter the numerator for frac2 '))
n4 = int(input('Enter the denominator for frac2 '))

print(' the sum of fractions are :', n1/n2 + n3/n4)
# Out:
# Enter the numerator for frac1 5
# Enter the denominator for frac1 7
# Enter the numerator for frac2 8
# Enter the denominator for frac2 9
#  the sum of fractions are : 1.6031746031746033

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here
import math

h_t = float(input('heiight'))
b_t = float(input('breadth'))
l_t = float(input('length'))

h_g = float(input('height of glass'))
r_g = float(input('radius of glass'))

vol_tank = h_t *b_t * l_t
vol_glass = 3.14 * r_g * r_g * h_g


print(' the no of glasses :', math.floor(vol_tank/vol_glass))
# Out:
# heiight10
# breadth19
# length10
# height of glass5
# radius of glass2
#  the no of glasses : 30
